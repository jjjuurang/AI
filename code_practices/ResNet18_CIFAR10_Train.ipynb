# %% [markdown]
# <a href="https://colab.research.google.com/github/jjjuurang/AI/blob/main/code_practices/ResNet18_CIFAR10_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### ResNet18 모델 정의 및 인스턴스 초기화

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os


# ResNet18을 위해 최대한 간단히 수정한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, Identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


# ResNet18 함수 정의
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %% [markdown]
# #### 데이터셋(Dataset) 다운로드 및 불러오기

# %%
import torchvision
import torchvision.transforms as transforms

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# #### 환경 설정 및 학습(Training) 함수 정의

# %%
device = 'cuda'

net = ResNet18()
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

learning_rate = 0.1
file_name = 'resnet18_cifar10.pt'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 100:
        lr /= 10
    if epoch >= 150:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# #### 학습(Training) 진행

# %% [markdown]
# * 대략 20번의 epoch 이후에도 85%가량의 test accuracy를 얻을 수 있습니다.

# %%
# for epoch in range(0, 200):
for epoch in range(0, 20):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# [ Train epoch: 0 ]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Current batch: 0
# Current benign train accuracy: 0.09375
# Current benign train loss: 2.423633575439453
#
# Current batch: 100
# Current benign train accuracy: 0.2734375
# Current benign train loss: 1.8879048824310303
#
# Current batch: 200
# Current benign train accuracy: 0.3046875
# Current benign train loss: 1.9113450050354004
#
# Current batch: 300
# Current benign train accuracy: 0.359375
# Current benign train loss: 1.6603742837905884
#
# Total benign train accuarcy: 30.528
# Total benign train loss: 750.4318332672119
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 39.87
# Test average loss: 0.015885044753551483
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.4140625
# Current benign train loss: 1.550041675567627
#
# Current batch: 100
# Current benign train accuracy: 0.4140625
# Current benign train loss: 1.4477542638778687
#
# Current batch: 200
# Current benign train accuracy: 0.484375
# Current benign train loss: 1.4786348342895508
#
# Current batch: 300
# Current benign train accuracy: 0.4921875
# Current benign train loss: 1.4156197309494019
#
# Total benign train accuarcy: 47.412
# Total benign train loss: 553.8880134820938
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 46.61
# Test average loss: 0.014438898491859435
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.46875
# Current benign train loss: 1.4604178667068481
#
# Current batch: 100
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.2186243534088135
#
# Current batch: 200
# Current benign train accuracy: 0.6328125
# Current benign train loss: 1.2446610927581787
#
# Current batch: 300
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.0764844417572021
#
# Total benign train accuarcy: 58.82
# Total benign train loss: 447.629007935524
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 61.24
# Test average loss: 0.010757859981060028
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.640625
# Current benign train loss: 0.9087585806846619
#
# Current batch: 100
# Current benign train accuracy: 0.625
# Current benign train loss: 1.0656784772872925
#
# Current batch: 200
# Current benign train accuracy: 0.671875
# Current benign train loss: 1.0040267705917358
#
# Current batch: 300
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.9062876105308533
#
# Total benign train accuarcy: 66.108
# Total benign train loss: 372.0327168703079
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 67.05
# Test average loss: 0.009227376437187195
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.8692096471786499
#
# Current batch: 100
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.8310026526451111
#
# Current batch: 200
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.9057987928390503
#
# Current batch: 300
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.8894752264022827
#
# Total benign train accuarcy: 71.062
# Total benign train loss: 320.29695588350296
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 69.99
# Test average loss: 0.008439064073562623
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.8485603928565979
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5209628343582153
#
# Current batch: 200
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5875735282897949
#
# Current batch: 300
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.9460867643356323
#
# Total benign train accuarcy: 75.54
# Total benign train loss: 273.0937156677246
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 74.79
# Test average loss: 0.007068918296694755
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.5655310153961182
#
# Current batch: 100
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5190091729164124
#
# Current batch: 200
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6727074980735779
#
# Current batch: 300
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.8135459423065186
#
# Total benign train accuarcy: 79.016
# Total benign train loss: 238.0079651772976
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 68.27
# Test average loss: 0.009565275353193283
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5030086636543274
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4926134943962097
#
# Current batch: 200
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6640403866767883
#
# Current batch: 300
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5540345907211304
#
# Total benign train accuarcy: 80.736
# Total benign train loss: 217.03904604911804
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 74.93
# Test average loss: 0.0074079791843891145
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.630945086479187
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.48822617530822754
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5013850927352905
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4721193313598633
#
# Total benign train accuarcy: 82.586
# Total benign train loss: 196.63802874088287
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 81.02
# Test average loss: 0.005610209122300148
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4101957082748413
#
# Current batch: 100
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4738638699054718
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5088032484054565
#
# Current batch: 300
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.49513939023017883
#
# Total benign train accuarcy: 83.91
# Total benign train loss: 183.8144337385893
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 82.56
# Test average loss: 0.005175779724121094
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.4358617961406708
#
# Current batch: 100
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.44254210591316223
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4590420722961426
#
# Current batch: 300
# Current benign train accuracy: 0.875
# Current benign train loss: 0.39867284893989563
#
# Total benign train accuarcy: 84.858
# Total benign train loss: 171.66353525221348
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 80.19
# Test average loss: 0.006053993022441864
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.3712310791015625
#
# Current batch: 100
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5686817765235901
#
# Current batch: 200
# Current benign train accuracy: 0.875
# Current benign train loss: 0.41304510831832886
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5571292042732239
#
# Total benign train accuarcy: 85.964
# Total benign train loss: 160.91698798537254
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 83.75
# Test average loss: 0.004710698038339615
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.27511319518089294
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.40088629722595215
#
# Current batch: 200
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.4041288495063782
#
# Current batch: 300
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.39889222383499146
#
# Total benign train accuarcy: 86.598
# Total benign train loss: 152.0716883391142
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 80.9
# Test average loss: 0.005768703752756119
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3738653361797333
#
# Current batch: 100
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3061452805995941
#
# Current batch: 200
# Current benign train accuracy: 0.875
# Current benign train loss: 0.34019094705581665
#
# Current batch: 300
# Current benign train accuracy: 0.875
# Current benign train loss: 0.33765244483947754
#
# Total benign train accuarcy: 87.004
# Total benign train loss: 145.88335144519806
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 83.26
# Test average loss: 0.005109737035632133
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3316458463668823
#
# Current batch: 100
# Current benign train accuracy: 0.875
# Current benign train loss: 0.35117197036743164
#
# Current batch: 200
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.37674251198768616
#
# Current batch: 300
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.34527987241744995
#
# Total benign train accuarcy: 87.56
# Total benign train loss: 140.34302696585655
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 82.33
# Test average loss: 0.00522313185930252
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.25816866755485535
#
# Current batch: 100
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.26233914494514465
#
# Current batch: 200
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.44232550263404846
#
# Current batch: 300
# Current benign train accuracy: 0.875
# Current benign train loss: 0.4362550973892212
#
# Total benign train accuarcy: 88.13
# Total benign train loss: 133.47161316871643
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 84.63
# Test average loss: 0.004592190420627594
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.3389817178249359
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.3699895441532135
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.33232635259628296
#
# Current batch: 300
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.24340298771858215
#
# Total benign train accuarcy: 88.72
# Total benign train loss: 127.66004741191864
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 83.28
# Test average loss: 0.005106927666068077
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.24546697735786438
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.21750368177890778
#
# Current batch: 200
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.36145228147506714
#
# Current batch: 300
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.39695098996162415
#
# Total benign train accuarcy: 89.038
# Total benign train loss: 125.3918968141079
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 82.65
# Test average loss: 0.005316899937391281
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.24230170249938965
#
# Current batch: 100
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.28470829129219055
#
# Current batch: 200
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3722103536128998
#
# Current batch: 300
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.32436850666999817
#
# Total benign train accuarcy: 89.124
# Total benign train loss: 122.42371934652328
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 79.88
# Test average loss: 0.006530775833129883
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.875
# Current benign train loss: 0.30184462666511536
#
# Current batch: 100
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.17250758409500122
#
# Current batch: 200
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.18149687349796295
#
# Current batch: 300
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.25321659445762634
#
# Total benign train accuarcy: 89.428
# Total benign train loss: 118.26910881698132
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 80.17
# Test average loss: 0.006254670831561089
# Model Saved!
